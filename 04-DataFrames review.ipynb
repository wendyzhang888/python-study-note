# %% [markdown]
# # DataFrames
#
# [additional learning resources](https://www.w3schools.com/python/pandas/default.asp)
#
# Throughout the course, most of our data exploration will be done with DataFrames. DataFrames are an extremely powerful tool and a natural extension of the Pandas Series. By definition all a DataFrame is:
#
# **A Pandas DataFrame consists of multiple Pandas Series that share index values.**

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating a DataFrame from Python Objects

# %%
# Make sure the seed is in the same cell as the random call
# https://stackoverflow.com/questions/21494489/what-does-numpy-random-seed0-do
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))

# %%
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]], dtype=int32)

# %%
myindex = ['CA','NY','AZ','TX']

# %%
mycolumns = ['Jan','Feb','Mar']

# %%
df = pd.DataFrame(data=mydata)
df
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
df = pd.DataFrame(data=mydata,index=myindex)
df
# Out:
#      0   1   2
# CA  95  11  81
# NY  70  63  87
# AZ  75   9  77
# TX  40   4  63

# %%
df = pd.DataFrame(data=mydata,index=myindex,columns=mycolumns)
df
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %% [markdown]
# ##  Read CSV
# Comma Separated Values files are text files that use commas as field delimeters.<br>
# Unless you're running the virtual environment included with the course, you may need to install <tt>xlrd</tt> and <tt>openpyxl</tt>.<br>
# In your terminal/command prompt run:
#
#     conda install xlrd
#     conda install openpyxl
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# ### Understanding File Paths
#
# You have two options when reading a file with pandas:
#
# 1. If your .py file or .ipynb notebook is located in the **exact** same folder location as the .csv file you want to read, simply pass in the file name as a string, for example:
#
#         df = pd.read_csv('some_file.csv')
#
# 2. Pass in the entire file path if you are located in a different directory. The file path must be 100% correct in order for this to work. For example:
#
#         df = pd.read_csv("C:\\Users\\myself\\files\\some_file.csv")

# %% [markdown]
# #### Print your current directory file path with pwd

# %%
pwd
# Out:
# 'c:\\Users\\夏晨玲\\Desktop\\python-study-guide'

# %% [markdown]
# #### List the files in your current directory with ls

# %%
ls
# Out:
#  ������ C �еľ��� Windows
#  �������к��� C499-A19D
#
#  c:\Users\�ĳ���\Desktop\python-study-guide ��Ŀ¼
#
# 2026/05/22  10:48    <DIR>          .
# 2026/05/24  09:30    <DIR>          ..
# 2026/05/20  10:54            21,021 02-Python Crash Course Exercises.ipynb
# 2026/05/22  10:29            13,746 03-Series.ipynb
# 2026/05/20  10:51           137,599 04-DataFrames.ipynb
# 2026/05/20  10:51            25,195 05-NumPy-Arrays.ipynb
# 2026/05/20  10:51           950,947 06-Matplotlib-Basics.ipynb
# 2026/05/20  10:54            36,868 fundamental.ipynb
# 2026/01/28  08:51                20 README.md
# 2026/05/22  10:47            18,752 tips.csv
#                8 ���ļ�      1,204,148 �ֽ�
#                2 ��Ŀ¼ 34,899,460,096 �����ֽ�

# %%
df = pd.read_csv('tips.csv')# 把tips.csv的数据（dataset)加载(loading)进来，并且存入(store)df当中,此刻df这个dataframe当中就会存着所有的数据集

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %% [markdown]
# # Let's load our dataset into a Notebook!
#
# ----
# About this DataSet (in case you are interested)
#
# * Description
#     * One waiter recorded information about each tip he received over a period of a few months working in one restaurant. He collected several variables:
#
# * Format
#     * A data frame with 244 rows and 7 variables
#
# * Details
#     * tip in dollars,
#     * bill in dollars,
#     * sex of the bill payer,
#     * whether there were smokers in the party,
#     * day of the week,
#     * time of day,
#     * size of the party.
#
# In all he recorded 244 tips. The data was reported in a collection of case studies for business statistics (Bryant & Smith 1995).
#
# * References
#     * Bryant, P. G. and Smith, M (1995) Practical Data Analysis: Case Studies in Business Statistics. Homewood, IL: Richard D. Irwin Publishing:
#
# * Note: We created some additional columns with Fake data, including Name, CC Number, and Payment ID.
#
# ----

# %% [markdown]
# # DataFrames

# %% [markdown]
# ## Obtaining Basic Information About DataFrame

# %%
df.columns#打印出数据特征（features/attributes）
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(10)#把前十行数据打印出来，数字10可以改，如果不填入数字，就默认只打前五行
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251
# 5          Erik Smith   213140353657882    Sun9679
# 6  Kristopher Johnson  2223727524230344    Sun5985
# 7         Robert Buck  3514785077705092    Sun8157
# 8     Joseph Mcdonald  3522866365840377    Sun6820
# 9       Jerome Abbott  3532124519049786    Sun3775

# %%
df.tail(3)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
len(df)
# Out:
# 244

# %% [markdown]
# ## Selection and Indexing
#
# Let's learn how to retrieve information from a DataFrame.

# %% [markdown]
# ### COLUMNS

# %% [markdown]
# We will begin be learning how to extract information based on the columns

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# #### Grab a Single Column

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df['total_bill'])#series是单独一列
# Out:
# pandas.Series

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %% [markdown]
# #### Grab Multiple Columns

# %%
# Note how its a python list of column names! Thus the double brackets.
df[['total_bill','tip']]#超过一列以上都要用两个方括号，一列只要用一个方括号
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='str')

# %%
df[['tip','smoker','sex','size']]
# Out:
#       tip smoker     sex  size
# 0    1.01     No  Female     2
# 1    1.66     No    Male     3
# 2    3.50     No    Male     3
# 3    3.31     No    Male     2
# 4    3.61     No  Female     4
# ..    ...    ...     ...   ...
# 239  5.92     No    Male     3
# 240  2.00    Yes  Female     2
# 241  2.00    Yes    Male     2
# 242  1.75     No    Male     2
# 243  3.00     No  Female     2
#
# [244 rows x 4 columns]

# %% [markdown]
# #### Create New Columns

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 239       Michael Avila  5296068606052842    Sat2657
# 240      Monica Sanders  3506806155565404    Sat1766
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [244 rows x 11 columns]

# %%
df['test']=0

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  test
# 0    Christy Cunningham  3560325168603410    Sun2959     0
# 1        Douglas Tucker  4478071379779230    Sun4608     0
# 2        Travis Walters  6011812112971322    Sun4458     0
# 3      Nathaniel Harris  4676137647685994    Sun5260     0
# 4          Tonya Carter  4832732618637221    Sun2251     0
# ..                  ...               ...        ...   ...
# 239       Michael Avila  5296068606052842    Sat2657     0
# 240      Monica Sanders  3506806155565404    Sat1766     0
# 241          Keith Wong  6011891618747196    Sat3880     0
# 242        Dennis Dixon     4375220550950      Sat17     0
# 243     Michelle Hardin  3511451626698139    Thur672     0
#
# [244 rows x 12 columns]

# %%
df['test']='this is a test'#在一个已经创建的features下面，把它所有的值覆盖掉（overwrite）

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID            test
# 0    Christy Cunningham  3560325168603410    Sun2959  this is a test
# 1        Douglas Tucker  4478071379779230    Sun4608  this is a test
# 2        Travis Walters  6011812112971322    Sun4458  this is a test
# 3      Nathaniel Harris  4676137647685994    Sun5260  this is a test
# 4          Tonya Carter  4832732618637221    Sun2251  this is a test
# ..                  ...               ...        ...             ...
# 239       Michael Avila  5296068606052842    Sat2657  this is a test
# 240      Monica Sanders  3506806155565404    Sat1766  this is a test
# 241          Keith Wong  6011891618747196    Sat3880  this is a test
# 242        Dennis Dixon     4375220550950      Sat17  this is a test
# 243     Michelle Hardin  3511451626698139    Thur672  this is a test
#
# [244 rows x 12 columns]

# %%
df['age']=17
df['school']='uwo'

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID            test  age  \
# 0    Christy Cunningham  3560325168603410    Sun2959  this is a test   17
# 1        Douglas Tucker  4478071379779230    Sun4608  this is a test   17
# 2        Travis Walters  6011812112971322    Sun4458  this is a test   17
# 3      Nathaniel Harris  4676137647685994    Sun5260  this is a test   17
# 4          Tonya Carter  4832732618637221    Sun2251  this is a test   17
# ..                  ...               ...        ...             ...  ...
# 239       Michael Avila  5296068606052842    Sat2657  this is a test   17
# 240      Monica Sanders  3506806155565404    Sat1766  this is a test   17
# 241          Keith Wong  6011891618747196    Sat3880  this is a test   17
# 242        Dennis Dixon     4375220550950      Sat17  this is a test   17
# 243     Michelle Hardin  3511451626698139    Thur672  this is a test   17
#
#     school
# 0      uwo
# 1      uwo
# 2      uwo
# 3      uwo
# 4      uwo
# ..     ...
# 239    uwo
# 240    uwo
# 241    uwo
# 242    uwo
# 243    uwo
#
# [244 rows x 14 columns]

# %%
df['tip_percentage'] = 100* df['tip'] / df['total_bill']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID            test  age  \
# 0  Christy Cunningham  3560325168603410    Sun2959  this is a test   17
# 1      Douglas Tucker  4478071379779230    Sun4608  this is a test   17
# 2      Travis Walters  6011812112971322    Sun4458  this is a test   17
# 3    Nathaniel Harris  4676137647685994    Sun5260  this is a test   17
# 4        Tonya Carter  4832732618637221    Sun2251  this is a test   17
#
#   school  tip_percentage
# 0    uwo        5.944673
# 1    uwo       16.054159
# 2    uwo       16.658734
# 3    uwo       13.978041
# 4    uwo       14.680765

# %%
df['price_per_person'] = df['total_bill'] / df['size']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2          8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3          3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3          7.003333
# 3       23.68  3.31    Male     No  Sun  Dinner     2         11.840000
# 4       24.59  3.61  Female     No  Sun  Dinner     4          6.147500
#
#            Payer Name         CC Number Payment ID            test  age  \
# 0  Christy Cunningham  3560325168603410    Sun2959  this is a test   17
# 1      Douglas Tucker  4478071379779230    Sun4608  this is a test   17
# 2      Travis Walters  6011812112971322    Sun4458  this is a test   17
# 3    Nathaniel Harris  4676137647685994    Sun5260  this is a test   17
# 4        Tonya Carter  4832732618637221    Sun2251  this is a test   17
#
#   school  tip_percentage
# 0    uwo        5.944673
# 1    uwo       16.054159
# 2    uwo       16.658734
# 3    uwo       13.978041
# 4    uwo       14.680765

# %% [markdown]
# #### Adjust Existing Columns

# %%
# Because pandas is based on numpy, we get awesome capabilities with numpy's universal functions!
df['price_per_person'] = np.round(df['price_per_person'],2)#round up四舍五入

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID            test  age  \
# 0  Christy Cunningham  3560325168603410    Sun2959  this is a test   17
# 1      Douglas Tucker  4478071379779230    Sun4608  this is a test   17
# 2      Travis Walters  6011812112971322    Sun4458  this is a test   17
# 3    Nathaniel Harris  4676137647685994    Sun5260  this is a test   17
# 4        Tonya Carter  4832732618637221    Sun2251  this is a test   17
#
#   school  tip_percentage
# 0    uwo        5.944673
# 1    uwo       16.054159
# 2    uwo       16.658734
# 3    uwo       13.978041
# 4    uwo       14.680765

# %% [markdown]
# #### Remove Columns

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID            test  age  \
# 0    Christy Cunningham  3560325168603410    Sun2959  this is a test   17
# 1        Douglas Tucker  4478071379779230    Sun4608  this is a test   17
# 2        Travis Walters  6011812112971322    Sun4458  this is a test   17
# 3      Nathaniel Harris  4676137647685994    Sun5260  this is a test   17
# 4          Tonya Carter  4832732618637221    Sun2251  this is a test   17
# ..                  ...               ...        ...             ...  ...
# 239       Michael Avila  5296068606052842    Sat2657  this is a test   17
# 240      Monica Sanders  3506806155565404    Sat1766  this is a test   17
# 241          Keith Wong  6011891618747196    Sat3880  this is a test   17
# 242        Dennis Dixon     4375220550950      Sat17  this is a test   17
# 243     Michelle Hardin  3511451626698139    Thur672  this is a test   17
#
#     school  tip_percentage
# 0      uwo        5.944673
# 1      uwo       16.054159
# 2      uwo       16.658734
# 3      uwo       13.978041
# 4      uwo       14.680765
# ..     ...             ...
# 239    uwo       20.392697
# 240    uwo        7.358352
# 241    uwo        8.822232
# 242    uwo        9.820426
# 243    uwo       15.974441
#
# [244 rows x 15 columns]

# %%
df = df.drop("test",axis=1)#axis=1代表y轴，axis=0代表x轴

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  age school  \
# 0    Christy Cunningham  3560325168603410    Sun2959   17    uwo
# 1        Douglas Tucker  4478071379779230    Sun4608   17    uwo
# 2        Travis Walters  6011812112971322    Sun4458   17    uwo
# 3      Nathaniel Harris  4676137647685994    Sun5260   17    uwo
# 4          Tonya Carter  4832732618637221    Sun2251   17    uwo
# ..                  ...               ...        ...  ...    ...
# 239       Michael Avila  5296068606052842    Sat2657   17    uwo
# 240      Monica Sanders  3506806155565404    Sat1766   17    uwo
# 241          Keith Wong  6011891618747196    Sat3880   17    uwo
# 242        Dennis Dixon     4375220550950      Sat17   17    uwo
# 243     Michelle Hardin  3511451626698139    Thur672   17    uwo
#
#      tip_percentage
# 0          5.944673
# 1         16.054159
# 2         16.658734
# 3         13.978041
# 4         14.680765
# ..              ...
# 239       20.392697
# 240        7.358352
# 241        8.822232
# 242        9.820426
# 243       15.974441
#
# [244 rows x 14 columns]

# %%
df=df.drop('age',axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID school  tip_percentage
# 0    Christy Cunningham  3560325168603410    Sun2959    uwo        5.944673
# 1        Douglas Tucker  4478071379779230    Sun4608    uwo       16.054159
# 2        Travis Walters  6011812112971322    Sun4458    uwo       16.658734
# 3      Nathaniel Harris  4676137647685994    Sun5260    uwo       13.978041
# 4          Tonya Carter  4832732618637221    Sun2251    uwo       14.680765
# ..                  ...               ...        ...    ...             ...
# 239       Michael Avila  5296068606052842    Sat2657    uwo       20.392697
# 240      Monica Sanders  3506806155565404    Sat1766    uwo        7.358352
# 241          Keith Wong  6011891618747196    Sat3880    uwo        8.822232
# 242        Dennis Dixon     4375220550950      Sat17    uwo        9.820426
# 243     Michelle Hardin  3511451626698139    Thur672    uwo       15.974441
#
# [244 rows x 13 columns]

# %%
df=df.drop('school',axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# 0    Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1        Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2        Travis Walters  6011812112971322    Sun4458       16.658734
# 3      Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4          Tonya Carter  4832732618637221    Sun2251       14.680765
# ..                  ...               ...        ...             ...
# 239       Michael Avila  5296068606052842    Sat2657       20.392697
# 240      Monica Sanders  3506806155565404    Sat1766        7.358352
# 241          Keith Wong  6011891618747196    Sat3880        8.822232
# 242        Dennis Dixon     4375220550950      Sat17        9.820426
# 243     Michelle Hardin  3511451626698139    Thur672       15.974441
#
# [244 rows x 12 columns]

# %%
# df.drop('tip_percentage',axis=1)

# %%
df = df.drop("tip_percentage",axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # Index Basics
#
# Before going over the same retrieval tasks for rows, let's build some basic understanding of the pandas DataFrame Index.

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.set_index('Payment ID')#把选定的feature作为index
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
# ...                      ...                 ...               ...
# Sat2657                 9.68       Michael Avila  5296068606052842
# Sat1766                13.59      Monica Sanders  3506806155565404
# Sat3880                11.34          Keith Wong  6011891618747196
# Sat17                   8.91        Dennis Dixon     4375220550950
# Thur672                 9.39     Michelle Hardin  3511451626698139
#
#             tip_percentage
# Payment ID
# Sun2959           5.944673
# Sun4608          16.054159
# Sun4458          16.658734
# Sun5260          13.978041
# Sun2251          14.680765
# ...                    ...
# Sat2657          20.392697
# Sat1766           7.358352
# Sat3880           8.822232
# Sat17             9.820426
# Thur672          15.974441
#
# [244 rows x 11 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#             tip_percentage
# Payment ID
# Sun2959           5.944673
# Sun4608          16.054159
# Sun4458          16.658734
# Sun5260          13.978041
# Sun2251          14.680765

# %%
df = df.reset_index()#重置index

# %%
df.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number  tip_percentage
# 0              8.49  Christy Cunningham  3560325168603410        5.944673
# 1              3.45      Douglas Tucker  4478071379779230       16.054159
# 2              7.00      Travis Walters  6011812112971322       16.658734
# 3             11.84    Nathaniel Harris  4676137647685994       13.978041
# 4              6.15        Tonya Carter  4832732618637221       14.680765

# %% [markdown]
# ### ROWS
#
# Let's now explore these same concepts but with Rows.

# %%
df.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %%
df = df.set_index('Payment ID')

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#             tip_percentage
# Payment ID
# Sun2959           5.944673
# Sun4608          16.054159
# Sun4458          16.658734
# Sun5260          13.978041
# Sun2251          14.680765

# %% [markdown]
# #### Grab a Single Row

# %%
# Integer Based
df.iloc[0]#iloc=index locate定位序列号
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# tip_percentage                5.944673
# Name: Sun2959, dtype: object

# %%
# Name Based
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# tip_percentage                5.944673
# Name: Sun2959, dtype: object

# %% [markdown]
# #### Grab Multiple Rows

# %%
df.iloc[0:4]#第0到第三列，不包含第四列
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
#
#             tip_percentage
# Payment ID
# Sun2959           5.944673
# Sun4608          16.054159
# Sun4458          16.658734
# Sun5260          13.978041

# %%
df.loc[['Sun2959','Sun5260']]#多行要两个方括号（square braket），单行一个括号
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %% [markdown]
# #### Remove Row
#
# Typically are datasets will be large enough that we won't remove rows like this since we won't know thier row location for some specific condition, instead, we drop rows based on conditions such as missing data or column values. The next lecture will cover this in a lot more detail.

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df.drop('Sun2959',axis=0).head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number  \
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994
# Sun2251                 6.15      Tonya Carter  4832732618637221
# Sun9679                 6.32        Erik Smith   213140353657882
#
#             tip_percentage
# Payment ID
# Sun4608          16.054159
# Sun4458          16.658734
# Sun5260          13.978041
# Sun2251          14.680765
# Sun9679          18.623962

# %%
# Error if you have a named index!
# df.drop(0,axis=0).head()

# %% [markdown]
# --------

# %% [markdown]
# # Conditional Filter（筛选）

# %% [markdown]
# ## Single Condition

# %%
bool_series = df['tip'] > 5
bool_series
# Out:
# Payment ID
# Sun2959    False
# Sun4608    False
# Sun4458    False
# Sun5260    False
# Sun2251    False
#            ...
# Sat2657     True
# Sat1766    False
# Sat3880    False
# Sat17      False
# Thur672    False
# Name: tip, Length: 244, dtype: bool

# %%
df[bool_series]
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sun2274          30.40   5.60    Male     No   Sun  Dinner     4
# Sun9677          32.40   6.00    Male     No   Sun  Dinner     4
# Sun6165          34.81   5.20  Female     No   Sun  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur7972         34.83   5.17  Female     No  Thur   Lunch     4
# Thur9003         24.71   5.85    Male     No  Thur   Lunch     2
# Sun22            29.93   5.07    Male     No   Sun  Dinner     4
# Thur1025         34.30   6.70    Male     No  Thur   Lunch     6
# Sun9176          29.85   5.14  Female     No   Sun  Dinner     5
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
# Sun9209           7.25   5.15    Male    Yes   Sun  Dinner     2
# Sun3402          23.33   5.65    Male    Yes   Sun  Dinner     2
# Sun6059          23.17   6.50    Male    Yes   Sun  Dinner     4
# Sat6735          25.89   5.16    Male    Yes   Sat  Dinner     4
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
# Sat3374          28.17   6.50  Female    Yes   Sat  Dinner     3
# Sat2657          29.03   5.92    Male     No   Sat  Dinner     3
#
#             price_per_person         Payer Name         CC Number
# Payment ID
# Sat239                  9.86     Lance Peterson  3542584061609808
# Sun2274                 7.60        Todd Cooper      503846761263
# Sun9677                 8.10       James Barnes  3552002592874186
# Sun6165                 8.70       Emily Daniel  4291280793094374
# Sat8139                12.07        Brian Ortiz  6596453823950595
# Thur7972                8.71        Shawna Cook  6011787464177340
# Thur9003               12.36       Roger Taylor     4410248629955
# Sun22                   7.48        Shawn Blake  4689079711213722
# Thur1025                5.72     Steven Carlson  3526515703718508
# Sun9176                 5.97     Madison Wilson  4210875236164664
# Sat1954                16.94      Gregory Clark  5473850968388236
# Sun9209                 3.62        Larry White    30432617123103
# Sun3402                11.66          Jason Cox  6556931703586223
# Sun6059                 5.79  Dr. Michael James     4718501859162
# Sat6735                 6.47     Christopher Li  6011962464150569
# Sat4590                12.08    Alex Williamson      676218815212
# Sat3374                 9.39    Marissa Jackson  4922302538691962
# Sat2657                 9.68      Michael Avila  5296068606052842

# %%
df[df['tip'] > 5]
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat239           39.42   7.58    Male     No   Sat  Dinner     4
# Sun2274          30.40   5.60    Male     No   Sun  Dinner     4
# Sun9677          32.40   6.00    Male     No   Sun  Dinner     4
# Sun6165          34.81   5.20  Female     No   Sun  Dinner     4
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Thur7972         34.83   5.17  Female     No  Thur   Lunch     4
# Thur9003         24.71   5.85    Male     No  Thur   Lunch     2
# Sun22            29.93   5.07    Male     No   Sun  Dinner     4
# Thur1025         34.30   6.70    Male     No  Thur   Lunch     6
# Sun9176          29.85   5.14  Female     No   Sun  Dinner     5
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
# Sun9209           7.25   5.15    Male    Yes   Sun  Dinner     2
# Sun3402          23.33   5.65    Male    Yes   Sun  Dinner     2
# Sun6059          23.17   6.50    Male    Yes   Sun  Dinner     4
# Sat6735          25.89   5.16    Male    Yes   Sat  Dinner     4
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
# Sat3374          28.17   6.50  Female    Yes   Sat  Dinner     3
# Sat2657          29.03   5.92    Male     No   Sat  Dinner     3
#
#             price_per_person         Payer Name         CC Number
# Payment ID
# Sat239                  9.86     Lance Peterson  3542584061609808
# Sun2274                 7.60        Todd Cooper      503846761263
# Sun9677                 8.10       James Barnes  3552002592874186
# Sun6165                 8.70       Emily Daniel  4291280793094374
# Sat8139                12.07        Brian Ortiz  6596453823950595
# Thur7972                8.71        Shawna Cook  6011787464177340
# Thur9003               12.36       Roger Taylor     4410248629955
# Sun22                   7.48        Shawn Blake  4689079711213722
# Thur1025                5.72     Steven Carlson  3526515703718508
# Sun9176                 5.97     Madison Wilson  4210875236164664
# Sat1954                16.94      Gregory Clark  5473850968388236
# Sun9209                 3.62        Larry White    30432617123103
# Sun3402                11.66          Jason Cox  6556931703586223
# Sun6059                 5.79  Dr. Michael James     4718501859162
# Sat6735                 6.47     Christopher Li  6011962464150569
# Sat4590                12.08    Alex Williamson      676218815212
# Sat3374                 9.39    Marissa Jackson  4922302538691962
# Sat2657                 9.68      Michael Avila  5296068606052842

# %%
df[df['sex'] == 'Male']
# Out:
#             total_bill   tip   sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66  Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50  Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31  Male     No  Sun  Dinner     2
# Sun9679          25.29  4.71  Male     No  Sun  Dinner     4
# Sun5985           8.77  2.00  Male     No  Sun  Dinner     2
# ...                ...   ...   ...    ...  ...     ...   ...
# Sat5032          12.60  1.00  Male    Yes  Sat  Dinner     2
# Sat2929          32.83  1.17  Male    Yes  Sat  Dinner     2
# Sat2657          29.03  5.92  Male     No  Sat  Dinner     3
# Sat3880          22.67  2.00  Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75  Male     No  Sat  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun9679                 6.32          Erik Smith   213140353657882
# Sun5985                 4.38  Kristopher Johnson  2223727524230344
# ...                      ...                 ...               ...
# Sat5032                 6.30       Matthew Myers  3543676378973965
# Sat2929                16.42        Thomas Brown  4284722681265508
# Sat2657                 9.68       Michael Avila  5296068606052842
# Sat3880                11.34          Keith Wong  6011891618747196
# Sat17                   8.91        Dennis Dixon     4375220550950
#
# [157 rows x 10 columns]

# %% [markdown]
# ## Multiple-condition

# %%
df[(df['total_bill'] > 30) & (df['sex']=='Male')]
# Out:
#             total_bill    tip   sex smoker   day    time  size  \
# Payment ID
# Sat239           39.42   7.58  Male     No   Sat  Dinner     4
# Sat6373          31.27   5.00  Male     No   Sat  Dinner     3
# Sun2274          30.40   5.60  Male     No   Sun  Dinner     4
# Sun9677          32.40   6.00  Male     No   Sun  Dinner     4
# Sat8903          38.01   3.00  Male    Yes   Sat  Dinner     4
# Sat8139          48.27   6.73  Male     No   Sat  Dinner     4
# Thur8801         32.68   5.00  Male    Yes  Thur   Lunch     2
# Fri9628          40.17   4.73  Male    Yes   Fri  Dinner     4
# Sun591           38.07   4.00  Male     No   Sun  Dinner     3
# Thur1025         34.30   6.70  Male     No  Thur   Lunch     6
# Thur3621         41.19   5.00  Male     No  Thur   Lunch     5
# Sun7518          48.17   5.00  Male     No   Sun  Dinner     6
# Sun3719          31.71   4.50  Male     No   Sun  Dinner     4
# Sat1954          50.81  10.00  Male    Yes   Sat  Dinner     3
# Sun9335          31.85   3.18  Male    Yes   Sun  Dinner     2
# Sun5109          32.90   3.11  Male    Yes   Sun  Dinner     2
# Sun9851          34.63   3.55  Male    Yes   Sun  Dinner     2
# Sun7544          34.65   3.68  Male    Yes   Sun  Dinner     4
# Sun2337          45.35   3.50  Male    Yes   Sun  Dinner     3
# Sun5140          40.55   3.00  Male    Yes   Sun  Dinner     2
# Sun9987          30.46   2.00  Male    Yes   Sun  Dinner     5
# Sat4505          38.73   3.00  Male    Yes   Sat  Dinner     4
# Sat8361          30.06   2.00  Male    Yes   Sat  Dinner     3
# Sat4590          48.33   9.00  Male     No   Sat  Dinner     4
# Sat2929          32.83   1.17  Male    Yes   Sat  Dinner     2
#
#             price_per_person             Payer Name         CC Number
# Payment ID
# Sat239                  9.86         Lance Peterson  3542584061609808
# Sat6373                10.42      Mr. Brandon Berry  6011525851069856
# Sun2274                 7.60            Todd Cooper      503846761263
# Sun9677                 8.10           James Barnes  3552002592874186
# Sat8903                 9.50  James Christensen DDS   349793629453226
# Sat8139                12.07            Brian Ortiz  6596453823950595
# Thur8801               16.34          Daniel Murphy  5356177501009133
# Fri9628                10.04          Aaron Bentley   180026611638690
# Sun591                 12.69             Jeff Lopez  3572865915176463
# Thur1025                5.72         Steven Carlson  3526515703718508
# Thur3621                8.24           Eric Andrews  4356531761046453
# Sun7518                 8.03          Ryan Gonzales  3523151482063321
# Sun3719                 7.93         Michael Lawson  3566285921227119
# Sat1954                16.94          Gregory Clark  5473850968388236
# Sun9335                15.92            Scott Perez  3577115550328507
# Sun5109                16.45        Nathan Reynolds   370307040837149
# Sun9851                17.32           Brian Bailey   346656312114848
# Sun7544                 8.66       James Hebert DDS      676168737648
# Sun2337                15.12           Jose Parsons  4112207559459910
# Sun5140                20.27            Stephen Cox  3547798222044029
# Sun9987                 6.09          David Barrett  4792882899700988
# Sat4505                 9.68          Ricky Ramirez   347817964484033
# Sat8361                10.02          Shawn Mendoza    30184049218122
# Sat4590                12.08        Alex Williamson      676218815212
# Sat2929                16.42           Thomas Brown  4284722681265508

# %%
# The Weekend
df[(df['day'] =='Sun') | (df['day']=='Sat')]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat9777          35.83  4.67  Female     No  Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
# ...                      ...                 ...               ...
# Sat9777                11.94      Kimberly Crane      676184013727
# Sat2657                 9.68       Michael Avila  5296068606052842
# Sat1766                13.59      Monica Sanders  3506806155565404
# Sat3880                11.34          Keith Wong  6011891618747196
# Sat17                   8.91        Dennis Dixon     4375220550950
#
# [163 rows x 10 columns]
